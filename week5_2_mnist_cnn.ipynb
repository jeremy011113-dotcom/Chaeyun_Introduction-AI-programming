# %% [markdown]
# # ✍️ 실습 2: MNIST 손글씨 숫자 인식 (CNN)
# > **AI Programming Course** — Konan Technology
#
# ---
#
# ## 학습 목표
# - MNIST 데이터셋을 로드하고 시각화한다
# - CNN(Convolutional Neural Network)을 PyTorch로 설계한다
# - `DataLoader`를 사용한 미니배치 학습을 구현한다
# - 학습 곡선, Confusion Matrix, Feature Map을 시각화한다
#
# ## 실습 구성
# | 단계 | 내용 |
# |:---:|------|
# | 1 | 환경 세팅 및 라이브러리 import |
# | 2 | MNIST 데이터 로드 & 시각화 |
# | 3 | CNN 모델 정의 (Conv2d, MaxPool, Dropout) |
# | 4 | DataLoader & 학습 루프 |
# | 5 | 정확도 평가 & 학습 곡선 시각화 |
# | 6 | 틀린 예측 분석 & Feature Map 시각화 |
# | 7 | ✏️ 도전 과제 |

# %% [markdown]
# ---
# ## Step 1: 환경 세팅

# %%
# !pip install torch torchvision matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: torch in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (2.11.0)
# Requirement already satisfied: torchvision in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (0.26.0)
# Requirement already satisfied: matplotlib in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (1.8.0)
# Requirement already satisfied: filelock in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\jerem\appdata\roaming\python\python311\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from torch) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from torch) (2026.3.0)
# Requirement already satisfied: numpy in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (2.4.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jerem\appdata\roaming\python\python311\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jerem\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tzdata in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\jerem\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jerem\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (3.0.3)
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# 재현성 시드
np.random.seed(42)
torch.manual_seed(42)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'PyTorch: {torch.__version__}')
print(f'Device : {device}')
# Out:
# PyTorch: 2.11.0+cpu
# Device : cpu

# %% [markdown]
# ---
# ## Step 2: MNIST 데이터 로드 & 시각화
#
# > `torchvision.datasets.MNIST`로 자동 다운로드합니다. (~11MB)
#
# **전처리 파이프라인:**
# - `ToTensor()`: PIL Image → Tensor `[0,255]` → `[0.0,1.0]`
# - `Normalize((0.1307,),(0.3081,))`: MNIST 전체 평균/표준편차로 정규화

# %%
# ─── 전처리 정의 ─────────────────────────────────────────────────────────
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST 공식 통계값
])

# ─── 데이터셋 다운로드 & 로드 ─────────────────────────────────────────────
train_dataset = datasets.MNIST(root='./data', train=True,  download=True, transform=transform)
test_dataset  = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

print(f'학습 데이터: {len(train_dataset):,}개')
print(f'테스트 데이터: {len(test_dataset):,}개')
print(f'이미지 크기: {train_dataset[0][0].shape}  (채널×높이×너비)')
print(f'클래스: {train_dataset.classes}')
# Out:
# 학습 데이터: 60,000개
# 테스트 데이터: 10,000개
# 이미지 크기: torch.Size([1, 28, 28])  (채널×높이×너비)
# 클래스: ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four', '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']

# %%
# ─── 샘플 이미지 시각화 ───────────────────────────────────────────────────
fig, axes = plt.subplots(4, 10, figsize=(16, 7))
fig.patch.set_facecolor('#0d1b2a')
fig.suptitle('MNIST 샘플 이미지 (숫자 0~9, 각 4개)', color='white', fontsize=14)

# 각 숫자별 샘플 찾기
samples = {i: [] for i in range(10)}
for img, label in train_dataset:
    if len(samples[label]) < 4:
        samples[label].append(img)
    if all(len(v) == 4 for v in samples.values()):
        break

for col, digit in enumerate(range(10)):
    for row in range(4):
        ax = axes[row][col]
        img = samples[digit][row].squeeze().numpy()
        ax.imshow(img, cmap='hot', vmin=-1, vmax=2)
        ax.axis('off')
        if row == 0:
            ax.set_title(str(digit), color='#00c9a7', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

# 픽셀 분포 히스토그램
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
fig.patch.set_facecolor('#0d1b2a')
for ax in [ax1, ax2]:
    ax.set_facecolor('#162236')
    ax.tick_params(colors='#7fa8c4')
    for sp in ax.spines.values():
        sp.set_edgecolor('#1e3a54')

# 원본 픽셀값 분포
raw = datasets.MNIST('./data', train=True, download=False,
                     transform=transforms.ToTensor())
pixels_raw = torch.stack([raw[i][0] for i in range(1000)]).numpy().flatten()
ax1.hist(pixels_raw, bins=50, color='#00c9a7', alpha=0.8, edgecolor='#0d1b2a')
ax1.set_title('정규화 전 픽셀 분포 [0,1]', color='white')
ax1.set_xlabel('픽셀 값', color='#7fa8c4')

# 정규화 후 픽셀값 분포
pixels_norm = torch.stack([train_dataset[i][0] for i in range(1000)]).numpy().flatten()
ax2.hist(pixels_norm, bins=50, color='#ffb74d', alpha=0.8, edgecolor='#0d1b2a')
ax2.set_title('정규화 후 픽셀 분포', color='white')
ax2.set_xlabel('픽셀 값 (표준화)', color='#7fa8c4')

plt.suptitle('MNIST 픽셀 분포', color='white', fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 49368 (\N{HANGUL SYLLABLE SAEM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 49707 (\N{HANGUL SYLLABLE SUS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:23: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49368 (\N{HANGUL SYLLABLE SAEM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49707 (\N{HANGUL SYLLABLE SUS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 54589 (\N{HANGUL SYLLABLE PIG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 49472 (\N{HANGUL SYLLABLE SEL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3425497614.py:50: UserWarning: Glyph 54980 (\N{HANGUL SYLLABLE HU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54589 (\N{HANGUL SYLLABLE PIG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49472 (\N{HANGUL SYLLABLE SEL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54980 (\N{HANGUL SYLLABLE HU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ---
# ## Step 3: CNN 모델 정의
#
# ```
# Input(1×28×28)
#   → Conv2d(1→32, 3×3) → BatchNorm → ReLU → MaxPool(2×2)   → (32×13×13)
#   → Conv2d(32→64, 3×3) → BatchNorm → ReLU → MaxPool(2×2)  → (64×5×5)
#   → Flatten → FC(1600→128) → Dropout(0.5)
#   → FC(128→10)
# ```
#
# | 레이어 | 역할 |
# |--------|------|
# | `Conv2d` | 필터로 엣지/곡선 등 공간 특징 추출 |
# | `BatchNorm2d` | 학습 안정화, 빠른 수렴 |
# | `MaxPool2d` | 공간 크기 축소, 위치 불변성 확보 |
# | `Dropout` | 과적합 방지 정규화 |

# %%
class MnistCNN(nn.Module):
    """
    MNIST 손글씨 분류를 위한 CNN 모델
    
    Architecture:
        Conv Block 1: Conv(1→32) → BN → ReLU → MaxPool
        Conv Block 2: Conv(32→64) → BN → ReLU → MaxPool
        Classifier:   FC(1600→128) → Dropout → FC(128→10)
    """
    def __init__(self, dropout_rate=0.7):
        super(MnistCNN, self).__init__()

        # ── 합성곱 블록 1 ──────────────────────────────────────────────
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32,
                      kernel_size=3, padding=1),  # 1×28×28 → 32×28×28
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # 32×28×28 → 32×14×14
        )

        # ── 합성곱 블록 2 ──────────────────────────────────────────────
        self.conv_block2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64,
                      kernel_size=3, padding=1),  # 32×14×14 → 64×14×14
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # 64×14×14 → 64×7×7
        )

        # ── 완전연결 분류기 ───────────────────────────────────────────
        self.classifier = nn.Sequential(
            nn.Flatten(),             # 64×7×7 = 3136
            nn.Linear(64 * 7 * 7, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(p=dropout_rate),
            nn.Linear(128, 10),
        )

    def forward(self, x):
        x = self.conv_block1(x)   # Conv Block 1
        x = self.conv_block2(x)   # Conv Block 2
        x = self.classifier(x)   # Classifier
        return x                  # raw logits (CrossEntropyLoss 사용)

    def get_feature_maps(self, x):
        """Feature Map 시각화를 위해 중간 출력 반환"""
        feat1 = self.conv_block1(x)
        feat2 = self.conv_block2(feat1)
        return feat1, feat2


model = MnistCNN(dropout_rate=0.7).to(device)
print(model)

# 파라미터 수 계산
total_params = sum(p.numel() for p in model.parameters())
train_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'\n총 파라미터 : {total_params:,}개')
print(f'학습 파라미터: {train_params:,}개')
# Out:
# MnistCNN(
#   (conv_block1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3136, out_features=128, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.7, inplace=False)
#     (4): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
#
# 총 파라미터 : 421,834개
# 학습 파라미터: 421,834개

# %%
# ─── 각 레이어의 출력 크기 확인 ──────────────────────────────────────────
dummy = torch.zeros(1, 1, 28, 28).to(device)
print('레이어별 출력 크기 추적:')
print(f'  Input         : {dummy.shape}')
out1 = model.conv_block1(dummy)
print(f'  Conv Block 1  : {out1.shape}')
out2 = model.conv_block2(out1)
print(f'  Conv Block 2  : {out2.shape}')
flat = out2.view(1, -1)
print(f'  Flatten       : {flat.shape}')
out_final = model(dummy)
print(f'  Output (logits): {out_final.shape}')
# Out:
# 레이어별 출력 크기 추적:
#   Input         : torch.Size([1, 1, 28, 28])
#   Conv Block 1  : torch.Size([1, 32, 14, 14])
#   Conv Block 2  : torch.Size([1, 64, 7, 7])
#   Flatten       : torch.Size([1, 3136])
#   Output (logits): torch.Size([1, 10])

# %% [markdown]
# ---
# ## Step 4: DataLoader 및 학습 루프
#
# > **미니배치(Mini-batch) 학습**: 전체 데이터를 `batch_size` 단위로 나눠
# > 각 배치마다 가중치를 업데이트합니다. 1 Epoch = 전체 데이터를 한 번 순회.

# %%
# ─── DataLoader ──────────────────────────────────────────────────────────
BATCH_SIZE = 128

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                          shuffle=True,  num_workers=0, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE,
                          shuffle=False, num_workers=0, pin_memory=True)

print(f'배치 크기: {BATCH_SIZE}')
print(f'학습 배치 수: {len(train_loader)}')
print(f'테스트 배치 수: {len(test_loader)}')

# 첫 배치 확인
images, labels = next(iter(train_loader))
print(f'\n첫 배치 이미지 형태: {images.shape}  (배치×채널×높이×너비)')
print(f'첫 배치 레이블 형태: {labels.shape}')
# Out:
# 배치 크기: 128
# 학습 배치 수: 469
# 테스트 배치 수: 79
#
# 첫 배치 이미지 형태: torch.Size([128, 1, 28, 28])  (배치×채널×높이×너비)
# 첫 배치 레이블 형태: torch.Size([128])

# %%
def train_one_epoch(model, loader, criterion, optimizer):
    """1 에폭 학습 함수."""
    model.train()
    total_loss, correct, total = 0.0, 0, 0
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += images.size(0)
    return total_loss / total, correct / total


@torch.no_grad()
def evaluate(model, loader, criterion):
    """평가 함수. (그래디언트 계산 없음)"""
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        total_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += images.size(0)
    return total_loss / total, correct / total

# %%
# ─── 하이퍼파라미터 ───────────────────────────────────────────────────────
NUM_EPOCHS    = 15
LEARNING_RATE = 0.001

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
# 학습률 스케줄러: 5 epoch마다 lr × 0.5
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

history = {'train_loss': [], 'train_acc': [], 'test_loss': [], 'test_acc': []}

print(f'학습 시작 (Epochs: {NUM_EPOCHS}, Batch: {BATCH_SIZE}, lr: {LEARNING_RATE})')
print(f'{"Epoch":>6} | {"Train Loss":>10} | {"Train Acc":>9} | {"Test Loss":>9} | {"Test Acc":>8} | {"LR":>8}')
print('-' * 65)

best_test_acc = 0.0

for epoch in range(1, NUM_EPOCHS + 1):
    tr_loss, tr_acc = train_one_epoch(model, train_loader, criterion, optimizer)
    te_loss, te_acc = evaluate(model, test_loader, criterion)
    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']

    history['train_loss'].append(tr_loss)
    history['train_acc'].append(tr_acc)
    history['test_loss'].append(te_loss)
    history['test_acc'].append(te_acc)

    # 최고 정확도 모델 저장
    if te_acc > best_test_acc:
        best_test_acc = te_acc
        torch.save(model.state_dict(), 'mnist_cnn_best.pth')
        mark = ' ⭐'
    else:
        mark = ''

    print(f'{epoch:>6} | {tr_loss:>10.4f} | {tr_acc*100:>8.2f}% | '
          f'{te_loss:>9.4f} | {te_acc*100:>7.2f}%{mark} | {current_lr:.6f}')

print(f'\n✅ 학습 완료!  최고 Test Accuracy: {best_test_acc*100:.2f}%')
# Out:
# 학습 시작 (Epochs: 15, Batch: 128, lr: 0.001)
#  Epoch | Train Loss | Train Acc | Test Loss | Test Acc |       LR
# -----------------------------------------------------------------
#      1 |     0.4026 |    87.09% |    0.0621 |   97.82% ⭐ | 0.001000
#      2 |     0.2045 |    93.24% |    0.0470 |   98.48% ⭐ | 0.001000
#      3 |     0.1749 |    94.25% |    0.0374 |   98.84% ⭐ | 0.001000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 19
#      16 best_test_acc = 0.0
#      18 for epoch in range(1, NUM_EPOCHS + 1):
# ---> 19     tr_loss, tr_acc = train_one_epoch(model, train_loader, criterion, optimizer)
#      20     te_loss, te_acc = evaluate(model, test_loader, criterion)
#      21     scheduler.step()
#
# Cell In[16], line 10, in train_one_epoch(model, loader, criterion, optimizer)
#       8 outputs = model(images)
#       9 loss = criterion(outputs, labels)
# ---> 10 loss.backward()
#      11 optimizer.step()
#      12 total_loss += loss.item() * images.size(0)
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py:381, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     376     retain_graph = create_graph
#     378 # The reason we repeat the same comment below is that
#     379 # some Python versions print out the first line of a multi-line function
#     380 # calls in the traceback and some print out the last line
# --> 381 _engine_run_backward(
#     382     tensors,
#     383     grad_tensors_,
#     384     retain_graph,
#     385     create_graph,
#     386     inputs_tuple,
#     387     allow_unreachable=True,
#     388     accumulate_grad=True,
#     389 )
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\graph.py:869, in _engine_run_backward(t_outputs, *args, **kwargs)
#     867     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     868 try:
# --> 869     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     870         t_outputs, *args, **kwargs
#     871     )  # Calls into the C++ engine to run the backward pass
#     872 finally:
#     873     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# ## Step 5: 학습 곡선 시각화

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))
fig.patch.set_facecolor('#0d1b2a')
epochs = range(1, NUM_EPOCHS + 1)

for ax in axes:
    ax.set_facecolor('#162236')
    ax.tick_params(colors='#7fa8c4')
    ax.set_xlabel('Epoch', color='#7fa8c4')
    for sp in ax.spines.values():
        sp.set_edgecolor('#1e3a54')
    ax.grid(alpha=0.2, color='#1e3a54')

# 손실 곡선
axes[0].plot(epochs, history['train_loss'], color='#00c9a7', lw=2, label='Train')
axes[0].plot(epochs, history['test_loss'],  color='#ffb74d', lw=2, label='Test', linestyle='--')
axes[0].set_title('Loss Curve', color='white', fontsize=13)
axes[0].set_ylabel('CrossEntropyLoss', color='#7fa8c4')
axes[0].legend(facecolor='#162236', labelcolor='white')

# 정확도 곡선
axes[1].plot(epochs, [a*100 for a in history['train_acc']], color='#00c9a7', lw=2, label='Train')
axes[1].plot(epochs, [a*100 for a in history['test_acc']],  color='#ffb74d', lw=2, label='Test', linestyle='--')
axes[1].axhline(y=99, color='#69f0ae', lw=1, linestyle=':', alpha=0.7, label='99% 목표')
axes[1].set_title('Accuracy Curve', color='white', fontsize=13)
axes[1].set_ylabel('Accuracy (%)', color='#7fa8c4')
axes[1].set_ylim(90, 101)
axes[1].legend(facecolor='#162236', labelcolor='white')

plt.suptitle('MNIST CNN 학습 곡선', color='white', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 fig, axes = plt.subplots(1, 2, figsize=(13, 5))
#       2 fig.patch.set_facecolor('#0d1b2a')
# ----> 3 epochs = range(1, NUM_EPOCHS + 1)
#       5 for ax in axes:
#       6     ax.set_facecolor('#162236')
#
# NameError: name 'NUM_EPOCHS' is not defined

# %% [markdown]
# ---
# ## Step 6: 결과 분석 및 시각화
#
# ### 6-1. Confusion Matrix

# %%
# ─── 최고 모델 로드 후 최종 평가 ─────────────────────────────────────────
model.load_state_dict(torch.load('mnist_cnn_best.pth', map_location=device))
model.eval()

all_preds, all_labels = [], []
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.numpy())

y_pred = np.array(all_preds)
y_true = np.array(all_labels)
final_acc = (y_pred == y_true).mean()

cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(9, 7))
fig.patch.set_facecolor('#0d1b2a')
ax.set_facecolor('#162236')
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=range(10), yticklabels=range(10),
            ax=ax, linewidths=0.5, linecolor='#0d1b2a',
            annot_kws={'size':11})
ax.set_title(f'Confusion Matrix  (Test Accuracy: {final_acc*100:.2f}%)',
             color='white', fontsize=13, pad=12)
ax.set_xlabel('예측 레이블', color='#7fa8c4', fontsize=11)
ax.set_ylabel('실제 레이블', color='#7fa8c4', fontsize=11)
ax.tick_params(colors='#7fa8c4')
plt.tight_layout()
plt.show()

print(classification_report(y_true, y_pred, target_names=[str(i) for i in range(10)]))
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\1028793463.py:32: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\1028793463.py:32: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\1028793463.py:32: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\1028793463.py:32: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\1028793463.py:32: UserWarning: Glyph 48660 (\N{HANGUL SYLLABLE BEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\1028793463.py:32: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\1028793463.py:32: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48660 (\N{HANGUL SYLLABLE BEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       980
#            1       1.00      0.99      1.00      1135
#            2       1.00      1.00      1.00      1032
#            3       0.99      1.00      0.99      1010
#            4       1.00      0.99      0.99       982
#            5       0.99      0.99      0.99       892
#            6       0.99      0.99      0.99       958
#            7       0.99      0.99      0.99      1028
#            8       0.99      1.00      0.99       974
#            9       0.99      0.99      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# ### 6-2. 틀린 예측 시각화

# %%
# ─── 틀린 예측 이미지 수집 ───────────────────────────────────────────────
wrong_images, wrong_preds, wrong_labels = [], [], []
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)
        _, predicted = torch.max(outputs, 1)
        mask = (predicted != labels.to(device))
        wrong_images.extend(images[mask].cpu())
        wrong_preds.extend(predicted[mask].cpu().numpy())
        wrong_labels.extend(labels[mask.cpu()].numpy())
        if len(wrong_images) >= 20:
            break

print(f'전체 오분류 샘플: {int((1-final_acc)*10000)}개 / 10,000개')

# 시각화
n_show = min(20, len(wrong_images))
fig, axes = plt.subplots(2, 10, figsize=(18, 4))
fig.patch.set_facecolor('#0d1b2a')
fig.suptitle('❌ 틀린 예측 이미지 (빨강=예측, 초록=실제)', color='white', fontsize=13)

for i in range(n_show):
    ax = axes[i//10][i%10]
    ax.imshow(wrong_images[i].squeeze(), cmap='gray')
    ax.set_title(f'P:{wrong_preds[i]}\nT:{wrong_labels[i]}',
                 color='#ff5252', fontsize=9)
    ax.axis('off')
    for sp in ax.spines.values():
        sp.set_edgecolor('#ff5252')
        sp.set_linewidth(2)
        sp.set_visible(True)

plt.tight_layout()
plt.show()
# Out:
# c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 전체 오분류 샘플: 66개 / 10,000개
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 53952 (\N{HANGUL SYLLABLE TEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 47536 (\N{HANGUL SYLLABLE RIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 48744 (\N{HANGUL SYLLABLE BBAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 47197 (\N{HANGUL SYLLABLE ROG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Local\Temp\ipykernel_8472\3254097799.py:36: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53952 (\N{HANGUL SYLLABLE TEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47536 (\N{HANGUL SYLLABLE RIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48744 (\N{HANGUL SYLLABLE BBAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47197 (\N{HANGUL SYLLABLE ROG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jerem\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 6-3. Feature Map 시각화
#
# > CNN이 이미지를 보는 방식: 각 필터가 어떤 특징을 감지하는지 확인합니다.

# %%
# ─── 테스트 이미지 1개 선택 ───────────────────────────────────────────────
sample_img, sample_label = test_dataset[0]
x = sample_img.unsqueeze(0).to(device)  # (1,1,28,28)

model.eval()
with torch.no_grad():
    feat1, feat2 = model.get_feature_maps(x)

print(f'입력 이미지 레이블: {sample_label}')
print(f'Conv Block 1 Feature Map: {feat1.shape}  → 32채널 × 14×14')
print(f'Conv Block 2 Feature Map: {feat2.shape}  → 64채널 × 7×7')

# ─── Conv Block 1 Feature Map (32개 필터) ────────────────────────────────
fig = plt.figure(figsize=(18, 6))
fig.patch.set_facecolor('#0d1b2a')
fig.suptitle(f'Conv Block 1 Feature Maps (숫자 "{sample_label}")  — 32 필터 × 14×14',
             color='white', fontsize=12)

# 원본 이미지
ax0 = fig.add_subplot(4, 9, 1)
ax0.imshow(sample_img.squeeze(), cmap='gray')
ax0.set_title('원본\n28×28', color='#00c9a7', fontsize=8)
ax0.axis('off')

# 각 필터의 특징 맵
for i in range(32):
    ax = fig.add_subplot(4, 9, i + 2)
    fm = feat1[0, i].cpu().numpy()
    ax.imshow(fm, cmap='viridis')
    ax.set_title(f'F{i+1}', color='#7fa8c4', fontsize=7)
    ax.axis('off')

plt.tight_layout()
plt.show()

# ─── 활성화 크기별 Top-8 필터 ────────────────────────────────────────────
activations = feat1[0].cpu().numpy()
mean_act = activations.mean(axis=(1,2))
top8_idx = np.argsort(mean_act)[::-1][:8]

fig, axes = plt.subplots(2, 4, figsize=(13, 5))
fig.patch.set_facecolor('#0d1b2a')
fig.suptitle(f'가장 강하게 활성화된 Top-8 필터 (숫자 "{sample_label}")', color='white', fontsize=12)
for i, idx in enumerate(top8_idx):
    ax = axes[i//4][i%4]
    fm = activations[idx]
    ax.imshow(fm, cmap='plasma')
    ax.set_title(f'필터 #{idx+1}  (활성: {mean_act[idx]:.2f})', color='#00c9a7', fontsize=9)
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## ✏️ Step 7: 도전 과제
#
# ### 🟢 기초
# 1. `batch_size`를 32, 128로 바꿔서 학습 속도와 정확도를 비교해보세요.
# 2. `Dropout` 비율을 0.3, 0.7로 변경해보세요. 과적합이 줄어드나요?
#
# ### 🟡 중급
# 3. Conv Layer를 하나 더 추가해보세요 (64→128 채널).
# 4. `BatchNorm2d`를 제거했을 때 학습이 어떻게 달라지나요?
# 5. 데이터 증강 (`RandomRotation`, `RandomAffine`)을 추가해보세요.
#
# ### 🔴 심화
# 6. 7-Segment 모델과 MNIST 모델의 정확도를 같은 그래프에 그려 비교하세요.
# 7. `torch.onnx.export()`로 모델을 ONNX 형식으로 저장해보세요.
# 8. Fashion-MNIST로 같은 모델을 학습하면 정확도가 어떻게 되나요?

# %%
# ✏️ 여기에 도전 과제 코드를 작성하세요!

# == batch_size ========================================
# 32 -> 1Epoch 당 82.5초 걸림 / 첫 Epoch 정확도 98.69%
# 128 -> 1Epoch 당 71.25초 걸림 / 첫 Epoch 정확도 99.3%
# ======================================================

# =============== Dropout ==============================
# 0.3
#      1 |     0.0968 |    97.04% |    0.0455 |   98.52% ⭐ | 0.001000
#      2 |     0.0572 |    98.26% |    0.0318 |   99.02% ⭐ | 0.001000
# 0.7
#      1 |     0.4026 |    87.09% |    0.0621 |   97.82% ⭐ | 0.001000
#      2 |     0.2045 |    93.24% |    0.0470 |   98.48% ⭐ | 0.001000
# ======================================================




# 예시: Fashion-MNIST 로드
# fashion_train = datasets.FashionMNIST('./data', train=True, download=True, transform=transform)
# fashion_test  = datasets.FashionMNIST('./data', train=False, download=True, transform=transform)
# ... (동일한 모델 구조로 학습)

print('도전 과제를 직접 구현해보세요! 🚀')
# Out:
# 도전 과제를 직접 구현해보세요! 🚀

# %%
# 중급 3번 문제

# 1. Conv Layer가 3개인 새로운 모델 클래스 정의 (이름: MnistCNN_Advanced)
class MnistCNN_Advanced(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(MnistCNN_Advanced, self).__init__()

        self.conv_block1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),
#            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.conv_block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
#            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        # ⭐️ 새로운 Conv Layer 블록 추가 (64 -> 128 채널)
        self.conv_block3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
#            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 3 * 3, 128),  # ⭐️ 입력 크기 수정
            nn.ReLU(inplace=True),
            nn.Dropout(p=dropout_rate),
            nn.Linear(128, 10),
        )

    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)  # ⭐️ 추가된 블록 통과
        x = self.classifier(x)
        return x

print("--- 🟡 중급 도전 과제: Conv Layer 추가 실험 시작 ---")

# 2. 새로운 모델 및 옵티마이저 초기화
model_advanced = MnistCNN_Advanced(dropout_rate=0.5).to(device)
criterion_adv = nn.CrossEntropyLoss()
optimizer_adv = optim.Adam(model_advanced.parameters(), lr=0.001)

# 파라미터 수 비교 출력
total_params_adv = sum(p.numel() for p in model_advanced.parameters())
print(f"새로운 모델 파라미터 수: {total_params_adv:,}개 (기존 모델 파라미터 대비 차이 확인)\n")

# 3. 새로운 모델 학습 루프 진행 (시간 절약을 위해 5 Epoch만 테스트)
NUM_EPOCHS_ADV = 5
print(f"▶ 학습 시작 (Epochs: {NUM_EPOCHS_ADV})")

for epoch in range(1, NUM_EPOCHS_ADV + 1):
    # 위쪽 셀에서 이미 정의된 train_one_epoch 및 evaluate 함수를 그대로 재사용합니다.
    tr_loss, tr_acc = train_one_epoch(model_advanced, train_loader, criterion_adv, optimizer_adv)
    te_loss, te_acc = evaluate(model_advanced, test_loader, criterion_adv)
    
    print(f"[Epoch {epoch:>2}/{NUM_EPOCHS_ADV}] "
          f"Train Loss: {tr_loss:.4f} | Train Acc: {tr_acc*100:.2f}% | "
          f"Test Loss: {te_loss:.4f} | Test Acc: {te_acc*100:.2f}%")

print("\n✅ Conv Layer 추가 모델 실험이 완료되었습니다!")
# Out:
# --- 🟡 중급 도전 과제: Conv Layer 추가 실험 시작 ---
# 새로운 모델 파라미터 수: 241,546개 (기존 모델 파라미터 대비 차이 확인)
#
# ▶ 학습 시작 (Epochs: 5)
# c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# [Epoch  1/5] Train Loss: 0.2929 | Train Acc: 90.89% | Test Loss: 0.0409 | Test Acc: 98.73%
# [Epoch  2/5] Train Loss: 0.0822 | Train Acc: 97.69% | Test Loss: 0.0338 | Test Acc: 98.78%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 62
#      58 print(f"▶ 학습 시작 (Epochs: {NUM_EPOCHS_ADV})")
#      60 for epoch in range(1, NUM_EPOCHS_ADV + 1):
#      61     # 위쪽 셀에서 이미 정의된 train_one_epoch 및 evaluate 함수를 그대로 재사용합니다.
# ---> 62     tr_loss, tr_acc = train_one_epoch(model_advanced, train_loader, criterion_adv, optimizer_adv)
#      63     te_loss, te_acc = evaluate(model_advanced, test_loader, criterion_adv)
#      65     print(f"[Epoch {epoch:>2}/{NUM_EPOCHS_ADV}] "
#      66           f"Train Loss: {tr_loss:.4f} | Train Acc: {tr_acc*100:.2f}% | "
#      67           f"Test Loss: {te_loss:.4f} | Test Acc: {te_acc*100:.2f}%")
#
# Cell In[9], line 8, in train_one_epoch(model, loader, criterion, optimizer)
#       6 images, labels = images.to(device), labels.to(device)
#       7 optimizer.zero_grad()
# ----> 8 outputs = model(images)
#       9 loss = criterion(outputs, labels)
#      10 loss.backward()
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# Cell In[15], line 42, in MnistCNN_Advanced.forward(self, x)
#      40 x = self.conv_block2(x)
#      41 x = self.conv_block3(x)  # ⭐️ 추가된 블록 통과
# ---> 42 x = self.classifier(x)
#      43 return x
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\dropout.py:73, in Dropout.forward(self, input)
#      69 def forward(self, input: Tensor) -> Tensor:
#      70     """
#      71     Runs the forward pass.
#      72     """
# ---> 73     return F.dropout(input, self.p, self.training, self.inplace)
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\functional.py:1443, in dropout(input, p, training, inplace)
#    1440 if p < 0.0 or p > 1.0:
#    1441     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
#    1442 return (
# -> 1443     _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#    1444 )
#
# KeyboardInterrupt:

# %% [markdown]
# ### Conv Layer 추가
# - [Epoch  1/5] Train Loss: 0.1916 | Train Acc: 94.34% | Test Loss: 0.0374 | Test Acc: 98.76%
# - [Epoch  2/5] Train Loss: 0.0657 | Train Acc: 98.11% | Test Loss: 0.0280 | Test Acc: 99.21%
# - Epoch 당 100초 정도 걸림
# ### BatchNorm2d 삭제
# - [Epoch  1/5] Train Loss: 0.2929 | Train Acc: 90.89% | Test Loss: 0.0409 | Test Acc: 98.73%
# - [Epoch  2/5] Train Loss: 0.0822 | Train Acc: 97.69% | Test Loss: 0.0338 | Test Acc: 98.78%
# - Epoch 당 95초 정도 걸림
# #### train 정확도와 test 정확도 모두 조금씩 떨어짐
#
# ### 데이터 증강 추가
# - [Epoch  1/5] Train Loss: 0.4178 | Train Acc: 86.64% | Test Loss: 0.0661 | Test Acc: 97.95%
# - [Epoch  2/5] Train Loss: 0.2047 | Train Acc: 93.78% | Test Loss: 0.0442 | Test Acc: 98.57%
# - Epoch 당 100초 정도 걸림
# #### 초기 train 정확도와 test 정확도가 모두 비교적 낮지만, Epoch가 많아질 수록 새로운 패턴에 대한 적응력이 생겨 과적합이 방지되고 실전 성능이 더 높아질 수 있음

# %%
# 중급 5번 문제

# 1. 데이터 증강(Augmentation)이 포함된 새로운 Transform 정의
train_transform_aug = transforms.Compose([
    transforms.RandomRotation(degrees=10),                    # ⭐️ 최대 ±10도 무작위 회전
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), # ⭐️ 상하좌우 최대 10% 무작위 이동
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 테스트 데이터는 증강을 적용하지 않습니다 (원본 그대로 평가하기 위함)
test_transform_base = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# 2. 새로운 Transform을 적용하여 데이터셋 다시 불러오기
train_dataset_aug = datasets.MNIST(root='./data', train=True, download=True, transform=train_transform_aug)
test_dataset_aug  = datasets.MNIST(root='./data', train=False, download=True, transform=test_transform_base)

# 3. 데이터가 바꼈으므로 DataLoader도 새롭게 생성
train_loader_aug = DataLoader(train_dataset_aug, batch_size=64, shuffle=True)
test_loader_aug  = DataLoader(test_dataset_aug, batch_size=64, shuffle=False)

print("--- 🟡 중급 5번: 데이터 증강(Data Augmentation) 실험 시작 ---")

# 4. 모델 및 최적화 도구 초기화 
# (여기서는 증강의 효과만 보기 위해 원본 MnistCNN 모델을 새로 불러와서 사용합니다)
model_aug = MnistCNN(dropout_rate=0.5).to(device)
criterion_aug = nn.CrossEntropyLoss()
optimizer_aug = optim.Adam(model_aug.parameters(), lr=0.001)

# 5. 새로운 DataLoader(train_loader_aug)를 사용하여 학습 루프 진행
NUM_EPOCHS_AUG = 5 # 테스트를 위해 5에폭만 진행
print(f"▶ 학습 시작 (Epochs: {NUM_EPOCHS_AUG})")

for epoch in range(1, NUM_EPOCHS_AUG + 1):
    # ⭐️ 기존 학습 함수에 새롭게 만든 증강 데이터 로더를 넣어줍니다.
    tr_loss, tr_acc = train_one_epoch(model_aug, train_loader_aug, criterion_aug, optimizer_aug)
    te_loss, te_acc = evaluate(model_aug, test_loader_aug, criterion_aug)
    
    print(f"[Epoch {epoch:>2}/{NUM_EPOCHS_AUG}] "
          f"Train Loss: {tr_loss:.4f} | Train Acc: {tr_acc*100:.2f}% | "
          f"Test Loss: {te_loss:.4f} | Test Acc: {te_acc*100:.2f}%")

print("\n✅ 데이터 증강 실험 완료! (원본 모델 학습 결과와 비교해보세요)")
# Out:
# --- 🟡 중급 5번: 데이터 증강(Data Augmentation) 실험 시작 ---
# ▶ 학습 시작 (Epochs: 5)
# [Epoch  1/5] Train Loss: 0.4319 | Train Acc: 86.26% | Test Loss: 0.0573 | Test Acc: 98.06%
# [Epoch  2/5] Train Loss: 0.2176 | Train Acc: 93.31% | Test Loss: 0.0383 | Test Acc: 98.80%
# [Epoch  3/5] Train Loss: 0.1816 | Train Acc: 94.48% | Test Loss: 0.0324 | Test Acc: 98.89%
# [Epoch  4/5] Train Loss: 0.1589 | Train Acc: 95.15% | Test Loss: 0.0293 | Test Acc: 98.94%
# [Epoch  5/5] Train Loss: 0.1413 | Train Acc: 95.73% | Test Loss: 0.0253 | Test Acc: 99.22%
#
# ✅ 데이터 증강 실험 완료! (원본 모델 학습 결과와 비교해보세요)

# %%
# 심화 6번 문제

import matplotlib.pyplot as plt

# 1. MNIST 모델의 테스트 정확도 (위쪽 셀에서 학습한 history 변수 재사용)
# history['test_acc'] 에는 0.0 ~ 1.0 사이의 값이 들어있으므로 보기 좋게 100을 곱해줍니다.
mnist_acc = [acc * 100 for acc in history['test_acc']]
epochs = range(1, len(mnist_acc) + 1)

# 2. 7-Segment 모델의 테스트 정확도 
# (week5_1 실습 결과를 바탕으로 직접 숫자를 기입하거나, 아래의 가상/대표적인 결과를 사용합니다)
# 7-Segment는 매우 쉬운 문제라 순식간에 100%에 도달하는 특징이 있습니다.
seg7_acc = [85.2, 92.5, 96.0, 98.5, 99.5, 100.0, 100.0, 100.0, 100.0, 100.0, 
            100.0, 100.0, 100.0, 100.0, 100.0]

# 혹시 MNIST 학습 에폭 수(NUM_EPOCHS)와 길이가 안 맞을 경우를 대비해 잘라주거나 늘려줍니다.
seg7_acc = seg7_acc[:len(mnist_acc)]
while len(seg7_acc) < len(mnist_acc):
    seg7_acc.append(100.0)

print("--- 🔴 심화 6번: 7-Segment vs MNIST 학습 곡선 비교 ---")

# 3. 같은 그래프에 비교해서 그리기
fig, ax = plt.subplots(figsize=(10, 6))
fig.patch.set_facecolor('#0d1b2a')
ax.set_facecolor('#162236')
ax.tick_params(colors='#7fa8c4')
for sp in ax.spines.values():
    sp.set_edgecolor('#1e3a54')
ax.grid(alpha=0.2, color='#1e3a54')

# 두 모델의 정확도 곡선 그리기 (색상과 마커 모양을 다르게 설정)
ax.plot(epochs, mnist_acc, color='#00c9a7', lw=2, marker='o', label='MNIST CNN (Complex Images)')
ax.plot(epochs, seg7_acc, color='#ffb74d', lw=2, marker='s', label='7-Segment MLP (Simple Vectors)')

# 그래프 꾸미기
ax.set_title('Test Accuracy Comparison: 7-Segment vs MNIST', color='white', fontsize=14)
ax.set_xlabel('Epoch', color='#7fa8c4', fontsize=12)
ax.set_ylabel('Test Accuracy (%)', color='#7fa8c4', fontsize=12)
ax.set_ylim(80, 102) # 정확도가 80~100 사이이므로 Y축 범위 제한
ax.legend(facecolor='#162236', labelcolor='white', fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 7
#       3 import matplotlib.pyplot as plt
#       5 # 1. MNIST 모델의 테스트 정확도 (위쪽 셀에서 학습한 history 변수 재사용)
#       6 # history['test_acc'] 에는 0.0 ~ 1.0 사이의 값이 들어있으므로 보기 좋게 100을 곱해줍니다.
# ----> 7 mnist_acc = [acc * 100 for acc in history['test_acc']]
#       8 epochs = range(1, len(mnist_acc) + 1)
#      10 # 2. 7-Segment 모델의 테스트 정확도
#      11 # (week5_1 실습 결과를 바탕으로 직접 숫자를 기입하거나, 아래의 가상/대표적인 결과를 사용합니다)
#      12 # 7-Segment는 매우 쉬운 문제라 순식간에 100%에 도달하는 특징이 있습니다.
#
# NameError: name 'history' is not defined

# %%
# 심화 6번 문제

import torch

print("--- 🔴 심화 7번: ONNX 포맷으로 모델 변환 및 저장 ---")

# 1. 모델을 평가(추론) 모드로 변경합니다. 
# (Dropout이나 BatchNorm이 학습 모드일 때와 다르게 동작해야 하므로 매우 중요합니다!)
model.eval()

# 2. 모델이 기대하는 입력 크기와 똑같은 '가짜(Dummy) 텐서'를 생성합니다.
# MNIST는 흑백 이미지이므로 (배치크기=1, 채널=1, 높이=28, 너비=28) 형태입니다.
dummy_input = torch.randn(1, 1, 28, 28).to(device)

# 3. 저장할 파일 이름 지정
onnx_file_path = "mnist_cnn_model.onnx"

# 4. torch.onnx.export() 함수로 변환 및 저장 실행
torch.onnx.export(
    model,                  # 변환할 PyTorch 모델
    dummy_input,            # 모델의 구조를 파악하기 위해 흘려보낼 가짜 데이터
    onnx_file_path,         # 저장될 파일 경로/이름
    export_params=True,     # 모델의 가중치(파라미터)를 파일 안에 포함할지 여부
    opset_version=11,       # ONNX 포맷 버전 (보통 11 또는 12를 많이 사용합니다)
    do_constant_folding=True, # 상수 폴딩 최적화 (더 빠른 추론을 위해)
    input_names=['input'],  # (선택) 입력 텐서의 이름을 지정
    output_names=['output'],# (선택) 출력 텐서의 이름을 지정
    dynamic_axes={'input': {0: 'batch_size'},    # (선택) 배치 크기(0번째 차원)를 
                  'output': {0: 'batch_size'}}   # 고정하지 않고 유동적으로 설정
)

print(f"✅ 모델이 성공적으로 '{onnx_file_path}' 파일로 저장되었습니다!")
print("주피터 노트북 왼쪽 폴더 목록(파일 탐색기)을 새로고침 해보시면 파일이 생성된 것을 볼 수 있습니다.")
# Out:
# --- 🔴 심화 7번: ONNX 포맷으로 모델 변환 및 저장 ---
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 19
#      16 onnx_file_path = "mnist_cnn_model.onnx"
#      18 # 4. torch.onnx.export() 함수로 변환 및 저장 실행
# ---> 19 torch.onnx.export(
#      20     model,                  # 변환할 PyTorch 모델
#      21     dummy_input,            # 모델의 구조를 파악하기 위해 흘려보낼 가짜 데이터
#      22     onnx_file_path,         # 저장될 파일 경로/이름
#      23     export_params=True,     # 모델의 가중치(파라미터)를 파일 안에 포함할지 여부
#      24     opset_version=11,       # ONNX 포맷 버전 (보통 11 또는 12를 많이 사용합니다)
#      25     do_constant_folding=True, # 상수 폴딩 최적화 (더 빠른 추론을 위해)
#      26     input_names=['input'],  # (선택) 입력 텐서의 이름을 지정
#      27     output_names=['output'],# (선택) 출력 텐서의 이름을 지정
#      28     dynamic_axes={'input': {0: 'batch_size'},    # (선택) 배치 크기(0번째 차원)를
#      29                   'output': {0: 'batch_size'}}   # 고정하지 않고 유동적으로 설정
#      30 )
#      32 print(f"✅ 모델이 성공적으로 '{onnx_file_path}' 파일로 저장되었습니다!")
#      33 print("주피터 노트북 왼쪽 폴더 목록(파일 탐색기)을 새로고침 해보시면 파일이 생성된 것을 볼 수 있습니다.")
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\onnx\__init__.py:286, in export(model, args, f, kwargs, verbose, input_names, output_names, opset_version, dynamo, external_data, dynamic_shapes, custom_translation_table, report, optimize, verify, profile, dump_exported_program, artifacts_dir, export_params, keep_initializers_as_inputs, dynamic_axes, training, operator_export_type, do_constant_folding, custom_opsets, export_modules_as_functions, autograd_inlining)
#     103 r"""Exports a model into ONNX format.
#     104
#     105 Setting ``dynamo=True`` enables the new ONNX export logic
#    (...)    281     ``fallback`` option has been removed.
#     282 """
#     283 if dynamo is True or isinstance(
#     284     model, (torch.export.ExportedProgram, ExportableModule)
#     285 ):
# --> 286     from torch.onnx._internal.exporter import _compat
#     288     if isinstance(args, torch.Tensor):
#     289         args = (args,)
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\onnx\_internal\exporter\_compat.py:16
#      14 from torch.onnx import _constants as onnx_constants
#      15 from torch.onnx._internal._lazy_import import onnx
# ---> 16 from torch.onnx._internal.exporter import (
#      17     _constants,
#      18     _core,
#      19     _dynamic_shapes,
#      20     _exportable_module,
#      21     _onnx_program,
#      22     _registration,
#      23 )
#      26 if TYPE_CHECKING:
#      27     import os
#
# File c:\Users\jerem\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\onnx\_internal\exporter\_core.py:19
#      16 from collections.abc import Callable, Mapping, Sequence
#      17 from typing import Any, Literal
# ---> 19 import onnxscript
#      20 import onnxscript.evaluator
#      21 from onnxscript import ir
#
# ModuleNotFoundError: No module named 'onnxscript'

# %%
# 심화 8번 문제

# 1. Fashion-MNIST 데이터셋 다운로드 및 로드 
# (위쪽 셀에서 정의해둔 동일한 transform을 그대로 재사용합니다)
fashion_train = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
fashion_test  = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# 2. Fashion-MNIST용 새로운 DataLoader 생성
fashion_train_loader = DataLoader(fashion_train, batch_size=64, shuffle=True)
fashion_test_loader  = DataLoader(fashion_test,  batch_size=64, shuffle=False)

print("--- 🔴 심화 8번: Fashion-MNIST 데이터셋 학습 비교 ---")
# 어떤 옷 종류들을 분류하는지 클래스 이름들을 출력해봅니다.
print(f"분류할 패션 아이템들: {fashion_train.classes}\n")

# 3. 새로운 모델 및 최적화 도구 초기화
# 숫자 MNIST를 학습시켰던 것과 "완전히 똑같은 구조"의 초기화된 모델을 꺼내옵니다.
model_fashion = MnistCNN(dropout_rate=0.5).to(device)
criterion_fash = nn.CrossEntropyLoss()
optimizer_fash = optim.Adam(model_fashion.parameters(), lr=0.001)

# 4. 새로운 DataLoader(fashion_train_loader)를 사용하여 학습 루프 진행
NUM_EPOCHS_FASH = 5  # 시간 절약을 위해 5에폭만 진행 (필요시 늘려보세요!)
print(f"▶ Fashion-MNIST 학습 시작 (Epochs: {NUM_EPOCHS_FASH})")

for epoch in range(1, NUM_EPOCHS_FASH + 1):
    # ⭐️ 기존 학습 함수에 숫자 대신 Fashion 데이터 로더를 넣어줍니다.
    tr_loss, tr_acc = train_one_epoch(model_fashion, fashion_train_loader, criterion_fash, optimizer_fash)
    te_loss, te_acc = evaluate(model_fashion, fashion_test_loader, criterion_fash)
    
    print(f"[Epoch {epoch:>2}/{NUM_EPOCHS_FASH}] "
          f"Train Loss: {tr_loss:.4f} | Train Acc: {tr_acc*100:.2f}% | "
          f"Test Loss: {te_loss:.4f} | Test Acc: {te_acc*100:.2f}%")

print("\n✅ Fashion-MNIST 모델 실험 완료! (숫자 모델의 정확도와 어떻게 다른지 비교해보세요)")
# Out:
# 100%|██████████| 26.4M/26.4M [00:08<00:00, 3.15MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 118kB/s]
# 100%|██████████| 4.42M/4.42M [00:04<00:00, 944kB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 2.50MB/s]
# --- 🔴 심화 8번: Fashion-MNIST 데이터셋 학습 비교 ---
# 분류할 패션 아이템들: ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
#
# ▶ Fashion-MNIST 학습 시작 (Epochs: 5)
# [Epoch  1/5] Train Loss: 0.4995 | Train Acc: 82.15% | Test Loss: 0.3648 | Test Acc: 86.28%
# [Epoch  2/5] Train Loss: 0.3520 | Train Acc: 87.29% | Test Loss: 0.2907 | Test Acc: 88.98%
# [Epoch  3/5] Train Loss: 0.3039 | Train Acc: 89.06% | Test Loss: 0.2757 | Test Acc: 89.94%
# [Epoch  4/5] Train Loss: 0.2753 | Train Acc: 90.03% | Test Loss: 0.2894 | Test Acc: 89.85%
# [Epoch  5/5] Train Loss: 0.2527 | Train Acc: 90.94% | Test Loss: 0.2399 | Test Acc: 91.24%
#
# ✅ Fashion-MNIST 모델 실험 완료! (숫자 모델의 정확도와 어떻게 다른지 비교해보세요)

# %% [markdown]
# ---
# ## 📝 정리
#
# | 항목 | 7-Segment MLP | MNIST CNN |
# |------|:---:|:---:|
# | 입력 | 7 (이진 벡터) | 784 (28×28 픽셀) |
# | 모델 | MLP 3층 | CNN (Conv×2 + FC×2) |
# | 파라미터 | ~500 | ~216,000 |
# | 기대 정확도 | ~100% | ~99% |
# | 핵심 개념 | 분류 기초, CrossEntropy | 공간 특징, Dropout |
#
# ### 다음 단계
# - **Transfer Learning**: ResNet, VGG 사전학습 모델 활용
# - **Data Augmentation**: 실제 데이터 다양성 확보
# - **Model Deployment**: ONNX, TorchScript, FastAPI 서빙
